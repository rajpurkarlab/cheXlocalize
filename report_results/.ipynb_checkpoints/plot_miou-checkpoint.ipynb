# %%
# %load_ext autoreload
# %autoreload 2

# %%
import glob
from PIL import Image, ImageDraw
import json
import pickle
import matplotlib.pyplot as plt
import numpy as np
import cv2
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Evaluation Results

# %%
results_dir = '/deep/group/aihc-bootcamp-spring2020/localize/eval_results'

# %%
ious = pd.read_csv(f'{results_dir}/gradcam/test_gradcam_ensemble_merged_iou_prob_threshold.csv')

# %%
method = 'gradcam'
model_type = 'ensemble'
phase = 'test'
save_dir = f'{results_dir}/{method}/{phase}_{method}_{model_type}_merged_summary_threshold.csv'
gradcam_threshold = pd.read_csv(save_dir)
gradcam_ptgame = pd.read_csv(f'{results_dir}/{method}/ptgame_gradcam_summary.csv')

# %%
save_dir = f'{results_dir}/{method}/{phase}_{method}_{model_type}_merged_summary_prob_threshold.csv'
gradcam_prob = pd.read_csv(save_dir)

# %%
save_dir = f'/deep/group/aihc-bootcamp-spring2020/localize/eval_results/human'
vietnam = pd.read_csv(f'{save_dir}/test_human_merged_summary.csv')
vietnam_ptgame = pd.read_csv(f'{save_dir}/ptgame_vietnam_summary.csv')

# %%
vietnam_ptgame.to_csv('fig2/vietnam_hit_ci.csv')

# %%
hit_diff = gradcam_ptgame.sort_values(['name']).rename(columns = {'mean':'gradcam'})
hit_diff['human'] = (vietnam_ptgame.sort_values(['name']))['mean'].tolist()
hit_diff['perct_diff'] = (hit_diff['human']-hit_diff['gradcam'])/hit_diff['gradcam']
hit_diff = hit_diff.sort_values(['perct_diff'],ascending = False).reset_index()

# %%
iou_diff = gradcam_prob.rename(columns = {'mean':'gradcam'})
iou_diff['human'] = vietnam['mean']
iou_diff['perct_diff'] = (iou_diff['human']-iou_diff['gradcam'])/iou_diff['gradcam']
iou_diff = iou_diff.sort_values(['perct_diff'],ascending = False).reset_index()

# %%
iou_diff
# Out:
#    index                        name  lower  gradcam  upper  human  perct_diff
# 0      6                 Lung Lesion  0.010    0.027  0.047  0.424   14.703704
# 1      5  Enlarged Cardiomediastinum  0.153    0.169  0.185  0.564    2.337278
# 2      8                Pneumothorax  0.047    0.124  0.206  0.393    2.169355
# 3      9             Support Devices  0.132    0.143  0.152  0.438    2.062937
# 4      2                Cardiomegaly  0.242    0.275  0.307  0.712    1.589091
# 5      4                       Edema  0.139    0.174  0.211  0.307    0.764368
# 6      3               Consolidation  0.056    0.087  0.123  0.148    0.701149
# 7      7            Pleural Effusion  0.130    0.158  0.188  0.213    0.348101
# 8      0            Airspace Opacity  0.175    0.193  0.211  0.232    0.202073
# 9      1                 Atelectasis  0.126    0.145  0.163  0.122   -0.158621

# %%
hit_diff
# Out:
#    index                        name  lower  gradcam  upper  human  perct_diff
# 0      5                 Lung Lesion  0.000    0.215  0.455  0.847    2.939535
# 1      8             Support Devices  0.210    0.258  0.307  0.955    2.701550
# 2      9                Pneumothorax  0.091    0.396  0.750  1.000    1.525253
# 3      1                 Atelectasis  0.289    0.357  0.427  0.869    1.434174
# 4      6            Airspace Opacity  0.317    0.373  0.430  0.653    0.750670
# 5      7            Pleural Effusion  0.356    0.441  0.528  0.749    0.698413
# 6      2                       Edema  0.523    0.630  0.733  0.818    0.298413
# 7      4  Enlarged Cardiomediastinum  0.712    0.761  0.810  0.953    0.252300
# 8      0                Cardiomegaly  0.857    0.903  0.945  0.972    0.076412
# 9      3               Consolidation  0.462    0.624  0.771  0.602   -0.035256

# %%
order_iou = iou_diff['name'].tolist()
order_hit = hit_diff['name'].tolist()

# %%
order_hit
# Out:
# ['Lung Lesion',
#  'Support Devices',
#  'Pneumothorax',
#  'Atelectasis',
#  'Airspace Opacity',
#  'Pleural Effusion',
#  'Edema',
#  'Enlarged Cardiomediastinum',
#  'Cardiomegaly',
#  'Consolidation']

# %%
map_order = dict(zip(order_iou,vietnam.name))
vietnam = vietnam.sort_values(by=['name'], key=lambda x: x.map(map_order))
map_order_gradcam = dict(zip(order_iou,gradcam_prob.name))
gradcam_prob = gradcam_prob.sort_values(by=['name'], key=lambda x: x.map(map_order_gradcam))

# %%
gradcam_prob['method'] = 'Grad-CAM'
vietnam['method'] = 'Benchmark'
rad_ai_iou = pd.DataFrame()
rad_ai_iou = rad_ai_iou.append([gradcam_prob,vietnam])

# %%
rad_ai_iou
# Out:
#                          name  lower   mean  upper     method
# 6                 Lung Lesion  0.010  0.027  0.047   Grad-CAM
# 5  Enlarged Cardiomediastinum  0.153  0.169  0.185   Grad-CAM
# 8                Pneumothorax  0.047  0.124  0.206   Grad-CAM
# 9             Support Devices  0.132  0.143  0.152   Grad-CAM
# 2                Cardiomegaly  0.242  0.275  0.307   Grad-CAM
# 4                       Edema  0.139  0.174  0.211   Grad-CAM
# 3               Consolidation  0.056  0.087  0.123   Grad-CAM
# 7            Pleural Effusion  0.130  0.158  0.188   Grad-CAM
# 0            Airspace Opacity  0.175  0.193  0.211   Grad-CAM
# 1                 Atelectasis  0.126  0.145  0.163   Grad-CAM
# 6                 Lung Lesion  0.266  0.424  0.584  Benchmark
# 5  Enlarged Cardiomediastinum  0.539  0.564  0.589  Benchmark
# 8                Pneumothorax  0.247  0.393  0.536  Benchmark
# 9             Support Devices  0.418  0.438  0.459  Benchmark
# 2                Cardiomegaly  0.692  0.712  0.731  Benchmark
# 4                       Edema  0.276  0.307  0.338  Benchmark
# 3               Consolidation  0.099  0.148  0.201  Benchmark
# 7            Pleural Effusion  0.185  0.213  0.244  Benchmark
# 0            Airspace Opacity  0.212  0.232  0.253  Benchmark
# 1                 Atelectasis  0.108  0.122  0.136  Benchmark

# %%
# Out:
# {'Lung Lesion': 0,
#  'Support Devices': 1,
#  'Pneumothorax': 2,
#  'Atelectasis': 3,
#  'Airspace Opacity': 4,
#  'Pleural Effusion': 5,
#  'Edema': 6,
#  'Enlarged Cardiomediastinum': 7,
#  'Cardiomegaly': 8,
#  'Consolidation': 9}

# %%
vietnam_ptgame = pd.read_csv(f'{save_dir}/ptgame_vietnam_summary.csv')
gradcam_ptgame = pd.read_csv(f'{results_dir}/{method}/ptgame_gradcam_summary.csv')
map_order = hit_diff['name'].to_dict()
inv_map = {v: k for k, v in map_order.items()}
vietnam_ptgame = vietnam_ptgame.sort_values(by=['name'], key=lambda x: x.map(inv_map))
# map_order_gradcam = dict(zip(order_hit,gradcam_ptgame.name.tolist()))
gradcam_ptgame = gradcam_ptgame.sort_values(by=['name'], key=lambda x: x.map(inv_map))

# %%
gradcam_ptgame['method'] = 'Grad-CAM'
vietnam_ptgame['method'] = 'Benchmark'
rad_ai_hit = pd.DataFrame()
rad_ai_hit = rad_ai_hit.append([gradcam_ptgame,vietnam_ptgame])

# %%
rad_ai_hit
# Out:
#                          name  lower   mean  upper     method
# 5                 Lung Lesion  0.000  0.215  0.455   Grad-CAM
# 8             Support Devices  0.210  0.258  0.307   Grad-CAM
# 9                Pneumothorax  0.091  0.396  0.750   Grad-CAM
# 1                 Atelectasis  0.289  0.357  0.427   Grad-CAM
# 6            Airspace Opacity  0.317  0.373  0.430   Grad-CAM
# 7            Pleural Effusion  0.356  0.441  0.528   Grad-CAM
# 2                       Edema  0.523  0.630  0.733   Grad-CAM
# 4  Enlarged Cardiomediastinum  0.712  0.761  0.810   Grad-CAM
# 0                Cardiomegaly  0.857  0.903  0.945   Grad-CAM
# 3               Consolidation  0.462  0.624  0.771   Grad-CAM
# 2                 Lung Lesion  0.625  0.847  1.000  Benchmark
# 9             Support Devices  0.931  0.955  0.977  Benchmark
# 7                Pneumothorax  1.000  1.000  1.000  Benchmark
# 6                 Atelectasis  0.815  0.869  0.918  Benchmark
# 3            Airspace Opacity  0.599  0.653  0.707  Benchmark
# 8            Pleural Effusion  0.669  0.749  0.824  Benchmark
# 4                       Edema  0.726  0.818  0.897  Benchmark
# 0  Enlarged Cardiomediastinum  0.927  0.953  0.976  Benchmark
# 1                Cardiomegaly  0.944  0.972  0.994  Benchmark
# 5               Consolidation  0.438  0.602  0.759  Benchmark

# %%
map_order
# Out:
# {'Lung Lesion': 'Enlarged Cardiomediastinum',
#  'Support Devices': 'Cardiomegaly',
#  'Pneumothorax': 'Lung Lesion',
#  'Atelectasis': 'Airspace Opacity',
#  'Airspace Opacity': 'Edema',
#  'Pleural Effusion': 'Consolidation',
#  'Edema': 'Atelectasis',
#  'Enlarged Cardiomediastinum': 'Pneumothorax',
#  'Cardiomegaly': 'Pleural Effusion',
#  'Consolidation': 'Support Devices'}

# %%
import matplotlib as mpc

lower = -vietnam['lower']+vietnam['mean']
upper = vietnam['upper']-vietnam['mean']
yerrs_vietnam = np.array([lower,upper])

lower = -gradcam_prob['lower']+gradcam_prob['mean']
upper = gradcam_prob['upper']-gradcam_prob['mean']
yerrs_gradcam = np.array([lower,upper])

task_labels = order_iou.copy()
task_labels[order_iou.index('Enlarged Cardiomediastinum')] = 'E. Cardiom.'
task_labels[order_iou.index('Airspace Opacity')] = 'A. Opacity'

colorway = ["#7e11d1","#8bfa37"]
plt.figure(figsize=(10,8))
g = sns.barplot(x="name", y="mean", hue = 'method',data=rad_ai_iou,palette = colorway, order = order_iou)
g.set_xticklabels(task_labels,fontsize=13,rotation=60,ha="right",rotation_mode="anchor")
plt.errorbar(np.arange(10)+0.18,iou_diff['human'], yerr=yerrs_vietnam, capsize=5,fmt=' ',c='black')
plt.errorbar(np.arange(10)-0.18,iou_diff['gradcam'], yerr=yerrs_gradcam, capsize=5,fmt=' ',c='black')
plt.tight_layout()
plt.legend(fontsize='xx-large')
leg_handles = g.get_legend_handles_labels()[0]
g.legend("",frameon=False)
# g.legend(leg_handles, ['Grad-CAM', 'Radiologists'],fontsize=13)
plt.xlabel('', fontsize=0)
plt.ylabel('mIoU', fontsize=14)
plt.ylim([0,1.1])
plt.savefig('fig2/miou_human_ai_prob_threshold.png',dpi = 300)

# %%
rad_ai_iou
# Out:
#                          name  lower   mean  upper     method
# 6                 Lung Lesion  0.010  0.027  0.047   Grad-CAM
# 5  Enlarged Cardiomediastinum  0.153  0.169  0.185   Grad-CAM
# 8                Pneumothorax  0.047  0.124  0.206   Grad-CAM
# 9             Support Devices  0.132  0.143  0.152   Grad-CAM
# 2                Cardiomegaly  0.242  0.275  0.307   Grad-CAM
# 4                       Edema  0.139  0.174  0.211   Grad-CAM
# 3               Consolidation  0.056  0.087  0.123   Grad-CAM
# 7            Pleural Effusion  0.130  0.158  0.188   Grad-CAM
# 0            Airspace Opacity  0.175  0.193  0.211   Grad-CAM
# 1                 Atelectasis  0.126  0.145  0.163   Grad-CAM
# 6                 Lung Lesion  0.266  0.424  0.584  Benchmark
# 5  Enlarged Cardiomediastinum  0.539  0.564  0.589  Benchmark
# 8                Pneumothorax  0.247  0.393  0.536  Benchmark
# 9             Support Devices  0.418  0.438  0.459  Benchmark
# 2                Cardiomegaly  0.692  0.712  0.731  Benchmark
# 4                       Edema  0.276  0.307  0.338  Benchmark
# 3               Consolidation  0.099  0.148  0.201  Benchmark
# 7            Pleural Effusion  0.185  0.213  0.244  Benchmark
# 0            Airspace Opacity  0.212  0.232  0.253  Benchmark
# 1                 Atelectasis  0.108  0.122  0.136  Benchmark

# %%
vietnam_ptgame = vietnam_ptgame.set_index('name',drop=False)
vietnam_ptgame
vietnam_ptgame = vietnam_ptgame.loc[order_hit, :]

# %%
gradcam_ptgame = gradcam_ptgame.set_index('name',drop=False)
gradcam_ptgame = gradcam_ptgame.loc[order_hit, :]

# %%
rad_ai_hit
# Out:
#                          name  lower   mean  upper     method
# 5                 Lung Lesion  0.000  0.215  0.455   Grad-CAM
# 8             Support Devices  0.210  0.258  0.307   Grad-CAM
# 9                Pneumothorax  0.091  0.396  0.750   Grad-CAM
# 1                 Atelectasis  0.289  0.357  0.427   Grad-CAM
# 6            Airspace Opacity  0.317  0.373  0.430   Grad-CAM
# 7            Pleural Effusion  0.356  0.441  0.528   Grad-CAM
# 2                       Edema  0.523  0.630  0.733   Grad-CAM
# 4  Enlarged Cardiomediastinum  0.712  0.761  0.810   Grad-CAM
# 0                Cardiomegaly  0.857  0.903  0.945   Grad-CAM
# 3               Consolidation  0.462  0.624  0.771   Grad-CAM
# 2                 Lung Lesion  0.625  0.847  1.000  Benchmark
# 9             Support Devices  0.931  0.955  0.977  Benchmark
# 7                Pneumothorax  1.000  1.000  1.000  Benchmark
# 6                 Atelectasis  0.815  0.869  0.918  Benchmark
# 3            Airspace Opacity  0.599  0.653  0.707  Benchmark
# 8            Pleural Effusion  0.669  0.749  0.824  Benchmark
# 4                       Edema  0.726  0.818  0.897  Benchmark
# 0  Enlarged Cardiomediastinum  0.927  0.953  0.976  Benchmark
# 1                Cardiomegaly  0.944  0.972  0.994  Benchmark
# 5               Consolidation  0.438  0.602  0.759  Benchmark

# %%
import matplotlib as mpc
lower = -vietnam_ptgame['lower']+vietnam_ptgame['mean']
upper = vietnam_ptgame['upper']-vietnam_ptgame['mean']
yerrs_vietnam = np.array([lower,upper])

lower = -gradcam_ptgame['lower']+gradcam_ptgame['mean']
upper = gradcam_ptgame['upper']-gradcam_ptgame['mean']
yerrs_gradcam = np.array([lower,upper])

task_labels = order_hit.copy()
task_labels[order_hit.index('Enlarged Cardiomediastinum')] = 'E. Cardiom.'
task_labels[order_hit.index('Airspace Opacity')] = 'A. Opacity'

colorway = ["#7e11d1","#8bfa37"]
plt.figure(figsize=(10,8))
g = sns.barplot(x="name", y="mean", hue = 'method',data=rad_ai_hit,palette = colorway, order = order_hit)
g.set_xticklabels(task_labels,fontsize=13,rotation=60,ha="right",rotation_mode="anchor")
plt.errorbar(np.arange(10)+0.18,hit_diff['human'], yerr=yerrs_vietnam, capsize=5,fmt=' ',c='black')
plt.errorbar(np.arange(10)-0.18,hit_diff['gradcam'], yerr=yerrs_gradcam, capsize=5,fmt=' ',c='black')
plt.tight_layout()
plt.legend(fontsize='xx-large')
leg_handles = g.get_legend_handles_labels()[0]
g.legend("",frameon=False)
# g.legend(leg_handles, ['Grad-CAM', 'Radiologists'],fontsize=13)
plt.xlabel('', fontsize=0)
plt.ylabel('Hit Accuracy', fontsize=14)
plt.ylim((0,1.1))
plt.savefig('fig2/ptgame_human_ai.png',dpi = 300)

# %%
import matplotlib as mpc
task_labels = order_iou.copy()
task_labels [order_iou.index('Enlarged Cardiomediastinum')] = 'E. Cardiom.'
task_labels [order_iou.index('Airspace Opacity')] = 'A. Opacity'

colorway = ["#7e11d1","#8bfa37"]
plt.figure(figsize=(12,10))
g = sns.barplot(x="task", y="mIoU", hue = 'method',data=human_ai_iou, ci = 'sd', capsize = .1,errwidth = 1.2, palette = colorway, order = order_iou)
g.set_xticklabels(task_labels,fontsize=13,rotation=60,ha="right",rotation_mode="anchor")

plt.tight_layout()
plt.legend(fontsize='xx-large')
leg_handles = g.get_legend_handles_labels()[0]
g.legend("",frameon=False)
# g.legend(leg_handles, ['Grad-CAM', 'Radiologists'],fontsize=13)
plt.xlabel('', fontsize=0)
plt.ylabel('mIoU', fontsize=14)
plt.ylim([0,1])
plt.savefig('fig2/miou_human_ai_prob_threshold.png',dpi = 300)

# %%
import matplotlib as mpc

task_labels = order_hit.copy()
task_labels [order_hit.index('Enlarged Cardiomediastinum')] = 'E. Cardiom.'
task_labels [order_hit.index('Airspace Opacity')] = 'A. Opacity'

colorway = ["#7e11d1","#8bfa37"]
plt.figure(figsize=(12,10))
g = sns.barplot(x="task", y="Hit Accuracy", hue = 'method',data=human_ai_pt, ci = 'sd', capsize = .1,errwidth = 1.2, palette = colorway, order = order_hit)
g.set_xticklabels(task_labels,fontsize=13,rotation=60,ha="right",rotation_mode="anchor")

plt.tight_layout()
plt.legend(fontsize='xx-large')
leg_handles = g.get_legend_handles_labels()[0]
g.legend("",frameon=False)
# g.legend(leg_handles, ['Grad-CAM', 'Radiologists'],fontsize=13)
plt.xlabel('', fontsize=0)
plt.ylabel('Hit Accuracy', fontsize=14)
plt.savefig('fig2/ptgame_human_ai.png',dpi = 300)

# %%
ptgame_all = ensemble_all.copy()
ptgame_all['mIoU'] = ptgame_all['mIoU'].apply(lambda x: x +np.random.normal(0.1, 0.05, 1)[0])

# %%
labels = tasks
labels[0] = 'Enlarged Cardiom.'
colorway = ["#ff595e","#219ebc"]
plt.figure(figsize=(12,10))
g = sns.barplot(x="task", y="mIoU", hue = 'method',data=ptgame_all, ci = 'sd', capsize = .1,errwidth = 1.2, palette = colorway)
g.set_xticklabels(sorted(labels),rotation=60)

hatches = ['-', '+', 'x', '//', '*']

# Loop over the bars
for i,thisbar in enumerate(g.patches):
    # Set a different hatch for each bar
    thisbar.set_hatch(hatches[3])

    
mpc.rc('hatch', color='k', linewidth=.3)

plt.tight_layout()
plt.legend(fontsize=15, title_fontsize=15)
leg_handles = g.get_legend_handles_labels()[0]
g.legend(leg_handles, ['GradCAM', 'IG with Noise Tunnel'])
plt.savefig('miou_ensemble_all.png')

# %%
human_ai
# Out:
#                   task      mIoU                      method
# 0     Airspace Opacity  0.139785  gradcam_ensemble_threshold
# 1     Airspace Opacity  0.128816  gradcam_ensemble_threshold
# 2     Airspace Opacity  0.126681  gradcam_ensemble_threshold
# 3     Airspace Opacity  0.131376  gradcam_ensemble_threshold
# 4     Airspace Opacity  0.135942  gradcam_ensemble_threshold
# ...                ...       ...                         ...
# 9995   Support Devices  0.438892                       human
# 9996   Support Devices  0.458657                       human
# 9997   Support Devices  0.448740                       human
# 9998   Support Devices  0.444585                       human
# 9999   Support Devices  0.439179                       human
#
# [20000 rows x 3 columns]

# %%
labels = tasks
labels[0] = 'Enlarged Cardiom.'
colorway = ["#219ebc",  "#f95d6a"]
plt.figure(figsize=(12,10))
g = sns.barplot(x="task", y="mIoU", hue = 'method',data=nt, ci = 'sd', capsize = .1,errwidth = 1.5, palette = colorway)
g.set_xticklabels(sorted(labels),rotation=60)
plt.tight_layout()
plt.legend(fontsize=15, title_fontsize=15)
leg_handles = g.get_legend_handles_labels()[0]
g.legend(leg_handles, ['GradCAM with Noise Tunnel (Thresholding)', 'GradCAM (thresholding)'])
plt.savefig('miou_nt.png')

# %%
labels = tasks
labels[0] = 'Enlarged Cardiom.'
colorway = ["#219ebc",  "#f95d6a"]
plt.figure(figsize=(12,10))
g = sns.barplot(x="task", y="mIoU", hue = 'method',data=threshold, ci = 'sd', capsize = .1,errwidth = 1.5, palette = colorway)
g.set_xticklabels(sorted(labels),rotation=60)
plt.tight_layout()
plt.legend(fontsize=15, title_fontsize=15)
leg_handles = g.get_legend_handles_labels()[0]
g.legend(leg_handles, ['GradCAM ( w/o Thresholding)', 'GradCAM (thresholding)'])
plt.savefig('miou_threshold.png')

# %%
# read auroc score

aucs = pd.read_csv('tables/AUROCs.csv',header=None)

# %%
aucs = aucs.rename(columns={0: "task", 1: "AUC"})

# %%
aucs['task'] = aucs['task'].apply(lambda x: x.split('_')[1])

# %%
aucs = aucs.loc[aucs['task'].isin(tasks)].reset_index(drop=True)

# %%
pt_gradcam = pd.read_csv('/deep/u/ashwinagrawal/eval/chexpert-model/Pointing_game_gradcam.csv')
gradcam_pt = pd.DataFrame(pt_gradcam.describe().loc['mean'])

# %%
gradcam_pt = gradcam_pt.sort_index()

# %%
gradcam_pt['mean']
# Out:
# Airspace Opacity              0.310680
# Atelectasis                   0.338983
# Cardiomegaly                  0.691429
# Consolidation                 0.657143
# Edema                         0.493976
# Enlarged Cardiomediastinum    0.707071
# Lung Lesion                   0.142857
# Pleural Effusion              0.450000
# Pneumothorax                  0.400000
# Support Devices               0.232484
# Name: mean, dtype: float64

# %%
df = aucs.copy()
df['mIoU'] = gradcam_threshold['mean']
df['Hit_Accuracy'] = gradcam_pt['mean'].tolist()

# %%
df
# Out:
#                          task     AUC   mIoU  Hit Accuracy
# 0            Airspace Opacity  0.8937  0.135      0.310680
# 1                 Atelectasis  0.8178  0.104      0.338983
# 2                Cardiomegaly  0.8994  0.194      0.691429
# 3               Consolidation  0.8392  0.048      0.657143
# 4                       Edema  0.9033  0.090      0.493976
# 5  Enlarged Cardiomediastinum  0.5493  0.184      0.707071
# 6                 Lung Lesion  0.9057  0.007      0.142857
# 7            Pleural Effusion  0.9545  0.072      0.450000
# 8                Pneumothorax  0.9932  0.010      0.400000
# 9             Support Devices  0.9634  0.099      0.232484

# %%
plt.scatter(df['mIoU'],df['AUC'])

# %%
#Create figure
plt.figure(figsize = (8,8))

# Create scatterplot. alpha controls the opacity and s controls the size.
ax = sns.scatterplot(data = df, x = "mIoU", y = "AUC")

ax.set_xlim(0,.5)
ax.set_ylim(.5, 1)

#For each point, we add a text inside the bubble
for line in range(0,df.shape[0]):
     ax.text(df["mIoU"][line], df["AUC"][line], df.task[line])

# %%
#Create figure
plt.figure(figsize = (8,8))

# Create scatterplot. alpha controls the opacity and s controls the size.
ax = sns.scatterplot(data = df, x = "Hit Accuracy", y = "AUC")

ax.set_xlim(0,1)
ax.set_ylim(0, 1)

#For each point, we add a text inside the bubble
for line in range(0,df.shape[0]):
     ax.text(df["Hit Accuracy"][line], df["AUC"][line], df.task[line])

# %%
import statsmodels.formula.api as smf
from scipy import stats

est = smf.ols(f"Hit_Accuracy ~ AUC", data = df)
est2 = est.fit()

#     corr = overall_regression[y].corr(overall_regression[feature], method='spearman')
pval = est2.pvalues.loc['AUC']
corr, corr_pval = stats.spearmanr(df['mIoU'].values,df['AUC'].values,nan_policy = 'omit')

# %%
est2.summary()
# Out:
# /sailhome/xgui/deep/u/xgui/envs/chexpert-baseline/lib/python3.7/site-packages/scipy/stats/stats.py:1535: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Hit_Accuracy   R-squared:                       0.272
# Model:                            OLS   Adj. R-squared:                  0.181
# Method:                 Least Squares   F-statistic:                     2.987
# Date:                Wed, 13 Jan 2021   Prob (F-statistic):              0.122
# Time:                        12:26:53   Log-Likelihood:                 4.2378
# No. Observations:                  10   AIC:                            -4.476
# Df Residuals:                       8   BIC:                            -3.870
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.1523      0.415      2.780      0.024       0.196       2.108
# AUC           -0.8141      0.471     -1.728      0.122      -1.900       0.272
# ==============================================================================
# Omnibus:                        0.128   Durbin-Watson:                   1.730
# Prob(Omnibus):                  0.938   Jarque-Bera (JB):                0.338
# Skew:                           0.008   Prob(JB):                        0.844
# Kurtosis:                       2.099   Cond. No.                         14.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
corr
# Out:
# -0.5515151515151515

# %%
corr_pval
# Out:
# 0.09840117666963498
